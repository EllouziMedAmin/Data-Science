# %% [markdown]
# <a href="https://colab.research.google.com/github/EllouziMedAmin/Data-Science/blob/main/run_ollama_in_google_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get update
# !apt-get install -y curl git

# %%
# !curl -fsSL https://ollama.com/install.sh | sh
# Out:
# >>> Installing ollama to /usr/local
# >>> Downloading Linux amd64 bundle
# ######################################################################## 100.0%
# >>> Creating ollama user...
# >>> Adding ollama user to video group...
# >>> Adding current user to ollama group...
# >>> Creating ollama systemd service...
# WARNING: systemd is not running
# WARNING: Unable to detect NVIDIA/AMD GPU. Install lspci or lshw to automatically detect and install GPU dependencies.
# >>> The Ollama API is now available at 127.0.0.1:11434.
# >>> Install complete. Run "ollama" from the command line.

# %%
# !nohup ollama serve > /dev/null 2>&1 &
# Out:
# !ollama pull llama3

# %%
# !ollama pull llama3.2
# Out:
# llama3
#
#
# pulling manifest ⠙
#
# pulling manifest ⠙ ssh-ed25519 AAAAC3NzaC1lZDI1NTE5AAAAID0qmkfzBAsBy2VGQE9uc82i2VomNtgm87zjmbYqG8
#
#
# pulling manifest ⠹ pulling manifest ⠼ pulling manifest ⠼ pulling manifest ⠴ pulling manifest ⠦ pulling manifest ⠇ pulling manifest ⠇ pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏    0 B/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   0% ▕▏ 137 KB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   1% ▕▏  18 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   4% ▕▏  90 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   7% ▕▏ 143 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...   8% ▕▏ 160 MB/2.0 GB                  pulling manifest
# pulling dde5aa3fc5ff...  10% ▕▏ 206 MB/2.0 GB                  pulling manifest
# ...

# %%
# !ollama list
# Out:
# NAME               ID              SIZE      MODIFIED
# llama3.2:latest    a80c4f17acd5    2.0 GB    34 seconds ago

# %%
# !ollama run llama3.2 "What's the capital of malaysia "
# Out:
# The capital of Malaysia is Kuala Lumpur.

# %%
# !ollama run llama3.2 "Explain quantum entanglement in simple terms."
# Out:
# Quantum entanglement is a fascinating phenomenon that's still not fully understood, but I'll try to explain it in simple terms.
#
# Imagine you have two toy cars, one red and one blue. They're separate and independent, with their own properties (like color and weight). But now, imagine that these cars are "linked" in such a way that what happens to one car instantly affects the other car, no matter how far apart they are.
#
# For example, if you spin the red car around in a circle, the blue car will start spinning in the opposite direction at the same instant, even if it's on the other side of the room. This is similar to what happens with entangled particles (like tiny atoms or photons) in quantum mechanics.
#
# Here are some key things to know about entanglement:
#
# 1. **It's a connection**: When two particles become entangled, they're connected in such a way that their properties are correlated.
# ...
